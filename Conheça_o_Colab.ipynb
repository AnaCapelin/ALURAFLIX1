# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaCapelin/ALURAFLIX1/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laço while True em Python

# %%
while True:
    # 1. Solicita ao usuário que digite um número
    try:
        numero = int(input("Digite um número (ou 0 para sair): "))
    except ValueError:
        print("Por favor, digite um número inteiro válido.")
        continue

    # 2. Verifica a condição de parada
    if numero == 0:
        print("Encerrando o programa. Até mais!")
        break

    # 3. Verifica se é par ou ímpar
    # Se o resto da divisão por 2 for 0, é par.
    if numero % 2 == 0:
        print(f"O número {numero} é PAR.")
    else:
        print(f"O número {numero} é ÍMPAR.")

print("Programa finalizado.")
# Out:
# Digite um número (ou 0 para sair): 1
# O número 1 é ÍMPAR.
# Digite um número (ou 0 para sair): 0
# Encerrando o programa. Até mais!
# Programa finalizado.

# %% [markdown]
# WHITE 2:

# %%
while True:
    # Solicita que o usuário digite um número
    try:
        numero = int(input("Digite um número (ou 0 para sair): "))
    except ValueError:
        print("Por favor, digite um número inteiro válido.")
        continue

    # Verifica a condição de parada
    if numero == 0:
        print("Encerrando o programa. Até mais!")
        break

    # Verifica se é par ou ímpar
    if numero % 2 == 0:
        print(f"O número {numero} é PAR.")
    else:
        print(f"O número {numero} é ÍMPAR.")
# Out:
# Digite um número (ou 0 para sair): 1
# O número 1 é ÍMPAR.
# Digite um número (ou 0 para sair): 5
# O número 5 é ÍMPAR.
# Digite um número (ou 0 para sair): 3
# O número 3 é ÍMPAR.
# Digite um número (ou 0 para sair): 2
# O número 2 é PAR.
